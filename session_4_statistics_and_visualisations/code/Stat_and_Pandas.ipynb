# %% [markdown]
# # Howdy ? 🤠
#
# ## We are going to talk about Pandas 🐼 , Matplotlib📊 and Seaborn 🐍

# %% [markdown]
# # So enough with yapping and let's gooooo straight to business !

# %% [markdown]
# ## So what's Pandas ?
# ### and I definitly don't mean this MF here
# <img src="Panda.webp" alt="image" width="460" height="420"/>

# %% [markdown]
# # 🐼 Pandas: Your Data Superhero! 🦸‍♂️✨
#
# ## **Pandas** is the ultimate data superhero for Python! 💨 It’s **fast**, **powerful**, and super easy to use, making data analysis and manipulation a breeze. 🌬️✨
#
# With its trusty sidekicks:
# - 📊 **DataFrame** (for tabular data, like a spreadsheet)
# - 📈 **Series** (for single columns, like a list on steroids),
#
# Pandas helps you clean, analyze, and transform your data like a pro! 🧹🔍 Whether you're filtering, grouping, or merging, Pandas has your back. 🛠️💪

# %%
# uncomment this line and run it to install pandas (you need to have pip installed 1st)
# ! pip install pandas

# %%
import pandas as pd

# %% [markdown]
# ### Let's build our 1st Dataframe
# ### - so as we discussed a Dataframe is data structure contains labeled axes (rows and columns) and Can be thought of as a dict-like container

# %%
# let's construct the Dictionary 1st 

students_data = {
    'Names' : ['Hossam' , 'Mario' , 'Mo' , 'Ziad'],
    'Age'   : [22 , 21 , 20 , 22 ],
    'Hobbies' : ["Chess" , "ML" , "FootBall" , "Gaming"]
}


# Converting it to Dataframe

students_Df = pd.DataFrame(data=students_data , columns=students_data.keys())

print(students_Df)
# Out:
#     Names  Age   Hobbies
# 0  Hossam   22     Chess
# 1   Mario   21        ML
# 2      Mo   20  FootBall
# 3    Ziad   22    Gaming

# %%
# so the question here , do we really need to do this on a daily basis ? HELL NOOOOO ! 
# usually we get our data in an excel or a csv form so we load it directly without doing all of this 

file_path = r"StudentsPerformance.csv"

df = pd.read_csv(file_path)

# %%
# to check the data of the 1st number of rows 

display(df.head(4)) # also check df.sample() and df.tail()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44

# %%
# we can check the data shape by this : 

print(df.shape)

print('-'*70)

# Basic Info about the Data 

display(df.info())
# Out:
# (1000, 8)
# ----------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
# None

# %%
# to check the Stats of the data 

display(df.describe())
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ### did you noticed something ? it's all numerical features in the describe function but where's the non numerical ones ? try to search it by yourself pls 👉👈

# %%
# checking  missing values
print("Missing values:")
display(df.isnull().sum())
# Out:
# Missing values:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ## Slicing

# %%
# Selecting a specific columns

display(df['gender'].head()) 

# we can also do this 

display(df.gender.head())
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
# filtering the Data
# you can select rows based on a certain condition like this 
display(df[df['gender'] == 'female'])
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# Slicing Works also here 
# df [rows(start : end (exclusive)]

display(df[10:11])
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 10   male        group C          associate's degree  standard
#
#    test preparation course  math score  reading score  writing score
# 10                    none          58             54             52

# %%
# but what if u want to slice the columns also 

display(df.iloc[10:11 , :3])
# Out:
#    gender race/ethnicity parental level of education
# 10   male        group C          associate's degree

# %%
# if u know the column name
# syntax -> df.loc[start_row : end_row(exculsive) ,  column_name]

display(df.loc[:5,'math score'])
# Out:
# 0    72
# 1    69
# 2    90
# 3    47
# 4    76
# 5    71
# Name: math score, dtype: int64

# %% [markdown]
# ## Creating new Columns

# %%
# in this new column i'll divide writing score by 100

df['New_writing_score'] = df['writing score'] / 100.0

display(df.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    New_writing_score
# 0               0.74
# 1               0.88
# 2               0.93
# 3               0.44
# 4               0.75

# %% [markdown]
# ## Dropping specific columns

# %%
df.drop(['New_writing_score'] , axis=1 , inplace=True)

# %%
# selecting specific datatypes
int_features = df.select_dtypes(include=['int64'])

display(int_features)
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Unique Values

# %%
# u can check the number of unique values in each faeture like this 

print(df.nunique())

print('-'*70)

# or u can count how many unique values in a specific column : 

print(df['gender'].value_counts())
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64
# ----------------------------------------------------------------------
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# ## Duplicates

# %%
# want to check for duplicates ? sure 

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Keep in mind, that's not all of it ! Pandas has a lot more to check, but that should keep you going for now.

# %% [markdown]
# # Matplotlib = 📈 Python's go-to tool for creating visualizations! 🚀
#
# ## Matplotlib is a **powerful Python library** for creating **static, animated, and interactive visualizations**. It offers:
#
# - 📈 **2D/3D plotting**: Line plots, scatter plots, bar charts, histograms, etc.
# - 🎨 **Customizable**: Colors, labels, styles, and more.
# - 🔄 **Integration**: Works seamlessly with Pandas, NumPy, and Jupyter.
#
#
# # Seaborn = 📈 Elegant statistical visualizations made easy! 🚀
# ## Seaborn is a Python data visualization library built on Matplotlib. It provides a high-level interface for creating statistical graphics with less code. Key features:
#
#  - 📊 Beautiful, ready-to-use plots (e.g., heatmaps, pair plots, violin plots).
#
#  - 🎨 Stylish defaults and easy customization.
#
#  - 🔗 Tight integration with Pandas DataFrames.
#
#
# ### Uncomment the following code to download it if u don't have it

# %%
# !pip install matplotlib

# %%
#!pip install seaborn

# %% [markdown]
# ## Histogram (visualize the distribution of numerical data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# let's create our 1st plot

plt.figure(figsize=(6,4)) # adjusting the figure size 
plt.hist(df['math score'], bins=20, color='skyblue', edgecolor='black') # customizing the plot
plt.title("Math Score Distribution") # setting the title 
plt.xlabel("Math score") # setting the x-axis label
plt.ylabel("Count") # setting the y-axis label 
plt.show() # Display the plot

# %%
# alternatively u can use seaborn to do the same 

plt.figure(figsize=(6,4))
sns.histplot(data=df, x='math score' , kde=True)  # Adds a smooth KDE curve
plt.title("Math Score Distribution") # setting the title 
plt.xlabel("Math score") # setting the x-axis label
plt.ylabel("Count") # setting the y-axis label 
plt.show() # Display the plot

# %% [markdown]
# ## Bar Chart (used to compare categorical data using rectangular bars)
#
# - Purpose of Bar Charts
# Compare Categories: Show differences between groups (e.g., sales by region).
#
# - Display Counts/Frequencies: Visualize how often categories occur.
#
# - Highlight Trends: Easily spot patterns or outliers in categorical data.

# %%
counts = df['gender'].value_counts()


plt.bar(data=df , x= counts.index , height= counts.values , color = ['cornflowerblue' , 'darksalmon'])
plt.xlabel('Gender')
plt.ylabel('Values')
plt.title('Bar Chart for Gender with Matplotlib')
plt.xticks(rotation = 45)
plt.show()

# %%
# now let's do it with seaborn

sns.barplot(x=counts.index, y=counts.values )
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Bar Chart for Gender with Seaborn')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Count plot (used to visualize the frequency of categorical data)

# %%
# Create a bar chart (manual count plot)
plt.bar(counts.index, counts.values, color=['cornflowerblue', 'darkslategray'])
plt.xlabel('Categories')
plt.ylabel('Count')
plt.title('Count Plot with Matplotlib')
plt.show()

# %%
# Count plot with seaborn
sns.countplot(data=df, x='gender')
plt.title('Count Plot')
plt.xlabel('Categories')
plt.ylabel('Count with seaborn')
plt.show()

# %% [markdown]
# # 🚨 TASK 🚨
# ##  so the question here what's the difference between Count plot and Bar plot ???????

# %% [markdown]
# ## Box plot
#  - (or whisker plot) is a statistical visualization used to summarize the distribution of numerical data. It provides insights into the data's central tendency, spread, and outliers

# %%
# look I prefer seaborn over Matplotlib in Box plot tbh but u can use whatever u like 

# Basic Box plot
sns.boxplot(data=df, x = 'math score')
plt.title('Box Plot of math score with Seaborn')
plt.show()

# %%
# Now let's customize it more !

sns.boxplot(data=df, y='math score' , x = 'gender' , hue='gender' , palette='BuPu')  
plt.title('Box Plot of Math Scores')
plt.ylabel('Math Score')
plt.legend()
plt.show()

# %% [markdown]
# ## Scatter plot (used to visualize the relationship between two numerical variables)

# %%
# using matplotlib

# Male plot
plt.scatter(x = 'math score', y = 'reading score', data= df[df['gender'] == 'male'] , color ='skyblue', alpha=0.5, label = 'Male' , s=45)
# female plot
plt.scatter(x = 'math score', y = 'reading score', data= df[df['gender'] == 'female'] , color ='salmon', alpha=0.5, label = 'Female' , s=45)
plt.xlabel('math scores')
plt.ylabel('reading score')
plt.title("student preformance in math & reading")
plt.legend()
plt.show()

# %%
# now seaborn

sns.scatterplot(data = df , x = 'math score' , y='reading score' , hue = 'gender' , alpha = 0.5 , palette=['salmon','skyblue'] )
plt.title('Math Score vs Reading Score')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ## Heat Map (used to visualize the correlation matrix)

# %%
# Step 1: Compute the correlation matrix
corr_matrix = df.corr()

# Step 2: Create the heatmap
plt.figure(figsize=(8, 6))  # Set the figure size
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ## Sub plots
# ### so do u see all the plots that we made ? what if we want to put all of that together in the same figure ? 🤔

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a 2x2 grid of subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 10))  # 2 rows, 2 columns, figure size 12x10

# Plot 1: Histogram of math score
sns.histplot(data=df, x='math score', kde=True, ax=axes[0, 0])  # Top-left
axes[0, 0].set_title('Distribution of Math Scores')

# Plot 2: Box plot of reading score by gender
sns.boxplot(data=df, x='gender', y='reading score', ax=axes[0, 1])  # Top-right
axes[0, 1].set_title('Reading Scores by Gender')

# Plot 3: Scatter plot of math score vs reading score
sns.scatterplot(data=df, x='math score', y='reading score', hue='gender', ax=axes[1, 0])  # Bottom-left
axes[1, 0].set_title('Math Score vs Reading Score')

# Plot 4: Heatmap of correlation matrix
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', ax=axes[1, 1])  # Bottom-right
axes[1, 1].set_title('Correlation Heatmap')

# Adjust layout and display
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finally ! we made it to the end 🫡
# # 📚 Resources Collection
#
#
# ---
# ## Docs :
# - [Matplotlib](https://matplotlib.org/3.5.3/api/_as_gen/matplotlib.pyplot.html)
# - [Seaborn](https://seaborn.pydata.org/tutorial.html)
# - [Pandas](https://pandas.pydata.org/docs/reference/)
#
# ## Tutorials :
# - [Pandas](https://youtu.be/gtjxAH8uaP0?si=IYLDzZpMJ7yJVP_H)
# - [Matplotlib](https://youtu.be/3Xc3CA655Y4?si=OzlUmbIMpNR6JPkw)
#
# ## Cheat sheets
# - [Pandas](https://media.datacamp.com/legacy/image/upload/v1676302204/Marketing/Blog/Pandas_Cheat_Sheet.pdf)
# - [Matplotlib](https://media.datacamp.com/legacy/image/upload/v1712136349/Marketing/Blog/Matplotlib_Cheat_Sheet.pdf)
# - [Seaborn](https://media.datacamp.com/legacy/image/upload/v1676302629/Marketing/Blog/Seaborn_Cheat_Sheet.pdf)
# ---
